# %% [markdown]
# # Q1

# %%
import pandas as pd
import json
import requests

# %%
url = "https://weatherbit-v1-mashape.p.rapidapi.com/forecast/3hourly"

querystring = {"lat":"35.5", "lon":"-78.5"}

headers = {
    "X-RapidAPI-Key": "a89141c87amsh570eb7f111f2761p189044jsne0c81ca55dcb",
    "X-RapidAPI-Host": "weatherbit-v1-mashape.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)
response = response.text
print(response)
# Out:
# {"data":[{"wind_cdir":"SSW","rh":87,"pod":"n","timestamp_utc":"2022-08-05T09:00:00","pres":1013,"solar_rad":0,"ozone":299.8,"weather":{"icon":"c04n","code":804,"description":"Overcast clouds"},"wind_gust_spd":5.89,"timestamp_local":"2022-08-05T05:00:00","snow_depth":0,"clouds":100,"ts":1659690000,"wind_spd":2.43,"pop":0,"wind_cdir_full":"south-southwest","slp":1019.5,"dni":0,"dewpt":20.5,"snow":0,"uv":0,"wind_dir":193,"clouds_hi":34,"precip":0,"vis":15,"dhi":0,"app_temp":23.4,"datetime":"2022-08-05:09","temp":22.8,"ghi":0,"clouds_mid":100,"clouds_low":1},{"wind_cdir":"SSW","rh":85,"pod":"d","timestamp_utc":"2022-08-05T12:00:00","pres":1014.5,"solar_rad":77.6846,"ozone":299.5,"weather":{"icon":"c04d","code":804,"description":"Overcast clouds"},"wind_gust_spd":6.48,"timestamp_local":"2022-08-05T08:00:00","snow_depth":0,"clouds":100,"ts":1659700800,"wind_spd":2.84,"pop":0,"wind_cdir_full":"south-southwest","slp":1021.5,"dni":620.89,"dewpt":22.8,"snow":0,"uv":0.6,"wind_dir":207,"clouds_h
# ...

# %%
json.loads(response)
# Out:
# {'data': [{'wind_cdir': 'SSW',
#    'rh': 87,
#    'pod': 'n',
#    'timestamp_utc': '2022-08-05T09:00:00',
#    'pres': 1013,
#    'solar_rad': 0,
#    'ozone': 299.8,
#    'weather': {'icon': 'c04n', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 5.89,
#    'timestamp_local': '2022-08-05T05:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1659690000,
#    'wind_spd': 2.43,
#    'pop': 0,
#    'wind_cdir_full': 'south-southwest',
#    'slp': 1019.5,
#    'dni': 0,
#    'dewpt': 20.5,
#    'snow': 0,
#    'uv': 0,
#    'wind_dir': 193,
#    'clouds_hi': 34,
#    'precip': 0,
#    'vis': 15,
#    'dhi': 0,
#    'app_temp': 23.4,
#    'datetime': '2022-08-05:09',
#    'temp': 22.8,
#    'ghi': 0,
#    'clouds_mid': 100,
#    'clouds_low': 1},
#   {'wind_cdir': 'SSW',
#    'rh': 85,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-05T12:00:00',
#    'pres': 1014.5,
#    'solar_rad': 77.6846,
#    'ozone': 299.5,
# ...

# %%
data = json.loads(response)
weather = pd.DataFrame(data)
ldata = pd.json_normalize(weather['data'])
ldata
# Out:
#    wind_cdir  rh pod        timestamp_utc    pres  solar_rad  ozone  \
# 0        SSW  87   n  2022-08-05T09:00:00  1013.0     0.0000  299.8
# 1        SSW  85   d  2022-08-05T12:00:00  1014.5    77.6846  299.5
# 2         SW  63   d  2022-08-05T15:00:00  1015.5   143.8160  300.3
# 3          S  42   d  2022-08-05T18:00:00  1014.0   923.4060  296.8
# 4          S  36   d  2022-08-05T21:00:00  1012.5   564.4790  293.0
# 5        SSE  55   d  2022-08-06T00:00:00  1013.0    27.1574  294.3
# 6        SSE  70   n  2022-08-06T03:00:00  1014.5     0.0000  294.0
# 7          S  84   n  2022-08-06T06:00:00  1014.5     0.0000  294.3
# 8          E  86   n  2022-08-06T09:00:00  1016.0     0.0000  297.3
# 9        SSE  88   d  2022-08-06T12:00:00  1017.0   231.2790  297.3
# 10         S  63   d  2022-08-06T15:00:00  1016.5   759.3710  298.5
# 11        SE  41   d  2022-08-06T18:00:00  1015.5   698.4130  297.3
# 12        SE  35   d  2022-08-06T21:00:00  1013.5   562.3050  299.0
# ...

# %% [markdown]
# # Q3

# %%
players = pd.read_html("https://www.premierleague.com/stats/top/players/goals?se=-1")
players
# Out:
# [    Rank                   Player               Club        Nationality  Stat  \
#  0      1             Alan Shearer                  -            England   260
#  1      2             Wayne Rooney                  -            England   208
#  2      3              Andrew Cole                  -            England   187
#  3      4            Sergio Agüero                  -          Argentina   184
#  4      5               Harry Kane  Tottenham Hotspur            England   183
#  5      6            Frank Lampard                  -            England   177
#  6      7            Thierry Henry                  -             France   175
#  7      8            Robbie Fowler                  -            England   163
#  8      9            Jermain Defoe                  -            England   162
#  9     10             Michael Owen                  -            England   150
#  10    11            Les Ferdinand                  -            England   149
# ...

# %%
players_df = players[0]
players_df
# Out:
#     Rank                   Player               Club        Nationality  Stat  \
# 0      1             Alan Shearer                  -            England   260
# 1      2             Wayne Rooney                  -            England   208
# 2      3              Andrew Cole                  -            England   187
# 3      4            Sergio Agüero                  -          Argentina   184
# 4      5               Harry Kane  Tottenham Hotspur            England   183
# 5      6            Frank Lampard                  -            England   177
# 6      7            Thierry Henry                  -             France   175
# 7      8            Robbie Fowler                  -            England   163
# 8      9            Jermain Defoe                  -            England   162
# 9     10             Michael Owen                  -            England   150
# 10    11            Les Ferdinand                  -            England   149
# ...

# %%
del players_df['Unnamed: 5']

# %%
players_df.head(3)
# Out:
#    Rank        Player Club Nationality  Stat
# 0     1  Alan Shearer    -     England   260
# 1     2  Wayne Rooney    -     England   208
# 2     3   Andrew Cole    -     England   187

# %% [markdown]
# # Q4

# %%
menu = pd.read_xml("breakfast_menu.xml")
menu.head()
# Out:
#                           name  price  \
# 0              Belgian Waffles  $5.95
# 1   Strawberry Belgian Waffles  $7.95
# 2  Berry-Berry Belgian Waffles  $8.95
# 3                 French Toast  $4.50
# 4          Homestyle Breakfast  $6.95
#
#                                          description  calories
# 0  Two of our famous Belgian Waffles with plenty ...       650
# 1  Light Belgian waffles covered with strawberrie...       900
# 2  Belgian waffles covered with assorted fresh be...       900
# 3  Thick slices made from our homemade sourdough ...       600
# 4  Two eggs, bacon or sausage, toast, and our eve...       950

# %%
del menu['description']
menu
# Out:
#                           name  price  calories
# 0              Belgian Waffles  $5.95       650
# 1   Strawberry Belgian Waffles  $7.95       900
# 2  Berry-Berry Belgian Waffles  $8.95       900
# 3                 French Toast  $4.50       600
# 4          Homestyle Breakfast  $6.95       950

# %%
menu['price'].replace('\$','', regex=True, inplace=True)
menu
# Out:
#                           name price  calories
# 0              Belgian Waffles  5.95       650
# 1   Strawberry Belgian Waffles  7.95       900
# 2  Berry-Berry Belgian Waffles  8.95       900
# 3                 French Toast  4.50       600
# 4          Homestyle Breakfast  6.95       950

# %%
menu.to_csv("breakfast_menu.csv",header=True, index=None, sep=";")

# %%
menu.head()
# Out:
#                           name price  calories
# 0              Belgian Waffles  5.95       650
# 1   Strawberry Belgian Waffles  7.95       900
# 2  Berry-Berry Belgian Waffles  8.95       900
# 3                 French Toast  4.50       600
# 4          Homestyle Breakfast  6.95       950

# %% [markdown]
# # Q5

# %%
iris = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
import numpy as np
answer = iris.aggregate(['mean', 'min' , 'max']).select_dtypes(include=np.number)

answer
# Out:
#       sepal_length  sepal_width  petal_length  petal_width
# mean      5.843333     3.057333         3.758     1.199333
# min       4.300000     2.000000         1.000     0.100000
# max       7.900000     4.400000         6.900     2.500000
